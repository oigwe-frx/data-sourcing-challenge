# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
#from dotenv import load_dotenv
import os
import pandas as pd
import json
from urllib.parse import urlencode
import re

# %%
# Set environment variables from the .env in the local environment
from google.colab import userdata
nyt_api_key = userdata.get('NYT_API_KEY')

tmdb_api_key=userdata.get('TMDB_API_KEY')

tmdb_access_token=userdata.get('TMDB_ACCESS_KEY')

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
params = {
  'api-key': nyt_api_key,
  'fq': filter_query,
  'sort': sort,
  'fl': field_list,
  'begin_date': begin_date,
  'end_date': end_date,
  }

# Construct the URL with properly encoded parameters
encoded_params = urlencode(params)
nyt_query_url = url + encoded_params

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # create query with a page number
    # API results show 10 articles at a time
    query_params = {
        'api-key': userdata.get('NYT_API_KEY'),
        'fq': filter_query,
        'sort': sort,
        'fl': field_list,
        'begin_date': begin_date,
        'end_date': end_date,
        'page': page
    }

    # Make a "GET" request and retrieve the JSON
    response = requests.get(url, params=query_params)
    reviews = response.json()

    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)


    #Try and save the reviews to the reviews_list
    try:
      if reviews["response"]["docs"]:

        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
          reviews_list.append(review)

        # Print the page that was just retrieved
        print(f"Checked page {page}")
    except:
        # Print the page number that had no results then break from the loop
        print(f"No results on page {page}, stopping.")
        break
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

reviews_list_strings = [json.dumps(movie, indent=4) for movie in reviews_list[:5]]

# Print the results to see the JSON strings of the first 5 entries
for movie_str in reviews_list_strings:
    print(movie_str)
# Out:
# {
#     "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#     "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "The Attachment Diaries",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "The Attachment Diaries (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Diment, Valentin Javier",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-25T11:00:03+0000",
#     "byline": {
#         "original": "By Jeannette Catsoulis",
#         "person": [
#             {
#                 "firstname": "Jeannette",
#                 "middlename": null,
#                 "lastname": "Catsoulis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 295
# }
# {
#     "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#     "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "What\u2019s Love Got to Do With It?",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Kapur, Shekhar",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "James, Lily",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Azmi, Shabana",
#             "rank": 4,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Thompson, Emma",
#             "rank": 5,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-04T17:16:45+0000",
#     "byline": {
#         "original": "By Jeannette Catsoulis",
#         "person": [
#             {
#                 "firstname": "Jeannette",
#                 "middlename": null,
#                 "lastname": "Catsoulis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 287
# }
# {
#     "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#     "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "You Can Live Forever",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "You Can Live Forever (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Slutsky, Mark",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Watts, Sarah (Film Director)",
#             "rank": 4,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "O'Driscoll, Anwen",
#             "rank": 5,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Laporte, June (Actor)",
#             "rank": 6,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-04T11:00:08+0000",
#     "byline": {
#         "original": "By Elisabeth Vincentelli",
#         "person": [
#             {
#                 "firstname": "Elisabeth",
#                 "middlename": null,
#                 "lastname": "Vincentelli",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 294
# }
# {
#     "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#     "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "A Tourist\u2019s  Guide to Love",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "A Tourist's Guide to Love (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Tsuchida, Steven",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Cook, Rachael Leigh",
#             "rank": 4,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-04-21T07:03:25+0000",
#     "byline": {
#         "original": "By Elisabeth Vincentelli",
#         "person": [
#             {
#                 "firstname": "Elisabeth",
#                 "middlename": null,
#                 "lastname": "Vincentelli",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 276
# }
# {
#     "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#     "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#         "kicker": "Critic\u2019s pick",
#         "content_kicker": null,
#         "print_headline": "Intoxicating Love With a Sobering Turn",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Zlotowski, Rebecca",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "Other People's Children (Movie)",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-04-20T15:35:13+0000",
#     "byline": {
#         "original": "By Manohla Dargis",
#         "person": [
#             {
#                 "firstname": "Manohla",
#                 "middlename": null,
#                 "lastname": "Dargis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 801
# }

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()

# Convert reviews_list to a Pandas DataFrame
reviews_df = pd.json_normalize(reviews_list)

# Print the DataFrame
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019.
# End string should include " Review" to avoid cutting title early


# Create a new column 'title' by extracting the title using a lambda function
reviews_df['title'] = reviews_df['headline.main'].apply(
    lambda st: st[st.find("\u2018")+1:st.rfind("\u2019 Review")]
)



# Print the DataFrame with the new column
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                          title
# 0       The Attachment Diaries
# 1                         What
# 2         You Can Live Forever
# 3                    A Tourist
# 4                 Other People
# ..                         ...
# 195             The Other Half
# 196     The Ottoman Lieutenant
# 197               Love & Taxes
# 198  Everybody Loves Somebody,
# 199                      Kedi,
#
# [200 rows x 17 columns]

# %%
reviews_df['keywords'][0]

def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};"
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Using the function
reviews_df['keywords'] = reviews_df['keywords'].apply(extract_keywords)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 195  subject: Movies;creative_works: The Other Half...
# 196  subject: Movies;creative_works: The Ottoman Li...
# 197  creative_works: Love & Taxes (Movie);persons: ...
# 198  subject: Movies;creative_works: Everybody Love...
# 199  creative_works: Kedi (Movie);subject: Document...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                          title
# 0       The Attachment Diaries
# 1                         What
# 2         You Can Live Forever
# 3                    A Tourist
# 4                 Other People
# ..                         ...
# 195             The Other Half
# 196     The Ottoman Lieutenant
# 197               Love & Taxes
# 198  Everybody Loves Somebody,
# 199                      Kedi,
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_df["title"].to_list()
titles
# Out:
# ['The Attachment Diaries',
#  'What',
#  'You Can Live Forever',
#  'A Tourist',
#  'Other People',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
#  'Cyrano',
#  'The In Between',
#  'Book of Love',
#  'Lingui, the Sacred Bonds',
#  'The Pink Cloud',
#  'A Journal for Jordan',
#  'West Side Story',
#  'Aulcie',
#  'Love Is Love Is Love',
#  'Love Hard',
#  'Bergman Island',
#  'Hard Luck Love Song',
#  'South of Heaven',
#  'Wife of a Spy',
#  'Happier Than Ever',
#  'Together',
#  'Annette',
#  'Resort to Love',
#  'Woodstock 99: Peace, Love and Rage',
#  'Casanova, Last Love',
#  'Running Against the Wind',
#  'Asia',
#  'Undine',
#  'This Town',
#  'Tu Me Manques',
#  'Monday',
#  'Ride or Die',
#  'Future People',
#  'Luz',
#  'Happily',
#  'This Is the Life',
#  'To All the Boys: Always and Forever',
#  'Young Hearts',
#  'Little Fish',
#  'Two of Us',
#  'Atlantis',
#  'Preparations to Be Together',
#  'Your Name Engraved Herein',
#  'Sylvie',
#  'Ariana Grande: Excuse Me, I Love You',
#  'Museum Town',
#  'Wild Mountain Thyme',
#  'My Psychedelic Love Story',
#  '69: The Saga of Danny Hernandez',
#  'Ammonite',
#  'Love and Monsters',
#  'Dick Johnson Is Dead',
#  'Love, Guaranteed',
#  'Feel the Beat',
#  'Babyteeth',
#  'Spelling the Dream',
#  'A Secret Love',
#  'Love Wedding Repeat',
#  'Almost Love',
#  'Hope Gap',
#  'All the Bright Places',
#  'The Photograph',
#  'You Go to My Head',
#  'Ordinary Love',
#  'To All the Boys: P.S. I Still Love You',
#  'The Woman Who Loves Giraffes',
#  'Queen & Slim',
#  'Marriage Story',
#  'Cyrano, My Love',
#  'Pretenders',
#  'First Love',
#  'Loro',
#  'Falling Inn Love',
#  'Hot Air',
#  'Love, Antosha',
#  'Leto',
#  'The Tomorrow Man',
#  'Asako I & II',
#  'The Sun Is Also a Star',
#  'Shéhérazade',
#  'Long Shot',
#  'Clara',
#  'Kalank',
#  'Rafiki',
#  'Diane',
#  'Five Feet Apart',
#  'Ash Is Purest White',
#  'Gloria Bell',
#  'Black Mother',
#  'The Hole in the Ground',
#  'How to Train Your Dragon: The Hidden World',
#  'A Tuba to Cuba',
#  'Fighting With My Family',
#  'Sorry Angel',
#  'Berlin, I Love You',
#  'Untogether',
#  'Cold War',
#  'If Beale Street Could Talk',
#  'Asher',
#  'The Party',
#  'The Great Pretender',
#  'Sicilian Ghost Story',
#  'The New Romantic',
#  'Pimp',
#  'In a Relationship',
#  'They',
#  'Burning,',
#  'After Everything,',
#  'Quincy',
#  'Love, Gilda,',
#  'Tea With the Dames,',
#  'Bel Canto,',
#  'The Citizen,',
#  'Love, Cecil,',
#  'How to Talk to Girls at Parties',
#  'Rogers Park,',
#  'Love & Bananas,',
#  'Godard Mon Amour',
#  'Submergence,',
#  'Love After Love,',
#  'Outside In',
#  'Love, Simon,',
#  'Keep the Change,',
#  'The Party',
#  'The Housemaid,',
#  'Forever My Girl,',
#  'Kangaroo: A Love-Hate Story',
#  'Lover for a Day',
#  'Youth,',
#  'Killing for Love',
#  'The Shape of Water',
#  'Love Beats Rhymes,',
#  'Cuba and the Cameraman',
#  'On the Beach at Night Alone',
#  'Thelma,',
#  'Hello Again,',
#  'It Happened in L.A.,',
#  'God',
#  'The Mountain Between Us',
#  'Dina,',
#  'In Search of Fellini',
#  'Woodpeckers,',
#  'I Do ... Until I Don',
#  'Tales of an Immoral Couple',
#  'After Love',
#  'The Last Face',
#  'Women Who Kill,',
#  'False Confessions,',
#  None,
#  'The Big Sick,',
#  'Lost in Paris',
#  'Vincent N Roxxy,',
#  'Everything, Everything',
#  'Hounds of Love',
#  'Harold and Lillian',
#  'The Happiest Day in the Life of Olli Maki,',
#  'The Promise',
#  'Frantz,',
#  'The Other Half',
#  'The Ottoman Lieutenant',
#  'Love & Taxes',
#  'Everybody Loves Somebody,',
#  'Kedi,']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Function to Extract Genre
def extract_genres(genre_list):
    extracted_genres = []
    for item in genre_list:
        # Extract 'name' and append the keyword item to the extracted_genres list
        extracted_genres.append(f"{item['name']}")
    return extracted_genres

# Function to Extract English Name of Movie
def extract_english_name(language_list):
    extracted_genres = []
    for item in language_list:
        # Extract the spoken_languages' English name into a list
        if item['english_name']:
          extracted_genres.append(f"{item['english_name']}")
    return extracted_genres

# Function to Extract Production Country of Movie
def extract_production_country(country_list):
    extracted_countries = []
    for item in country_list:
        # Extract the country_list' into a list
        extracted_countries.append(f"{item['name']}")
    return extracted_countries

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:

    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        time.sleep(1)

    # Add 1 to the request counter
    request_counter += 1

    # Perform a "GET" request for The Movie Database
    headers = {
      "accept": "application/json",
      "Authorization": f"Bearer {tmdb_access_token}"
    }

    response_general_query = requests.get(
      f"https://api.themoviedb.org/3/search/movie?query={title}",
      headers=headers
    )
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

    try:
        # Get movie id
        response_movies_id = response_general_query.json()["results"][0]["id"]

        # Make a request for a the full movie details
        # Execute "GET" request with url
        response_full_details = requests.get(
          f"https://api.themoviedb.org/3/movie/{response_movies_id}",
          headers=headers
        )
        # Extract the genre names into a list
        genres = extract_genres(response_full_details.json()["genres"])

        # Extract the spoken_languages' English name into a list
        spoken_languages = extract_english_name(response_full_details.json()["spoken_languages"])

        # Extract the production_countries' name into a list
        production_countries = extract_production_country(response_full_details.json()["production_countries"])

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_list.append({
            "title": response_full_details.json()['title'],
            "original_title": response_full_details.json()['original_title'],
            "budget": response_full_details.json()["budget"],
            "original_language": response_full_details.json()["original_language"],
            "homepage":response_full_details.json()["homepage"],
            "overview": response_full_details.json()["overview"],
            "popularity": response_full_details.json()["popularity"],
            "runtime" : response_full_details.json()["runtime"],
            "revenue": response_full_details.json()["revenue"],
            "release_date": response_full_details.json()["release_date"],
            "vote_average": response_full_details.json()["vote_average"],
            "vote_count": response_full_details.json()["vote_count"],
            "genres": genres,
            "spoken_languages": spoken_languages,
            "production_countries": production_countries

        })

        # Print out the title that was found
        print(f"Found {title}")
    except IndexError:
        print(f"{title} not found.")
# Out:
# Found The Attachment Diaries
# Found What
# Found You Can Live Forever
# Found A Tourist
# Found Other People
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Found Thor: Love and Thunder
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Found Benediction
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# Found See You Then
# Found La Mami
# Found Love After Love
# Found Deep Water
# Found Lucy and Desi
# Found Cyrano
# Found The In Between
# Found Book of Love
# Found Lingui, the Sacred Bonds
# Found The Pink Cloud
# Found A Journal for Jordan
# Found West Side Story
# Aulcie not found.
# Found Love Is Love Is Love
# Found Love Hard
# Found Bergman Island
# Found Hard Luck Love Song
# Found South of Heaven
# Found Wife of a Spy
# Found Happier Than Ever
# Found Together
# Found Annette
# Found Resort to Love
# Found Woodstock 99: Peace, Love and Rage
# Found Casanova, Last Love
# Found Running Against the Wind
# Found Asia
# Found Undine
# Found This Town
# Found Tu Me Manques
# Found Monday
# Found Ride or Die
# Found Future People
# Found Luz
# Found Happily
# Found This Is the Life
# Found To All the Boys: Always and Forever
# Found Young Hearts
# Found Little Fish
# Found Two of Us
# Found Atlantis
# Found Preparations to Be Together
# Found Your Name Engraved Herein
# Found Sylvie
# Found Ariana Grande: Excuse Me, I Love You
# Found Museum Town
# Found Wild Mountain Thyme
# Found My Psychedelic Love Story
# Found 69: The Saga of Danny Hernandez
# Found Ammonite
# Found Love and Monsters
# Found Dick Johnson Is Dead
# Found Love, Guaranteed
# Found Feel the Beat
# Found Babyteeth
# Found Spelling the Dream
# Found A Secret Love
# Found Love Wedding Repeat
# Found Almost Love
# Found Hope Gap
# Found All the Bright Places
# Found The Photograph
# Found You Go to My Head
# Found Ordinary Love
# Found To All the Boys: P.S. I Still Love You
# Found The Woman Who Loves Giraffes
# Found Queen & Slim
# Found Marriage Story
# Found Cyrano, My Love
# Found Pretenders
# Found First Love
# Found Loro
# Found Falling Inn Love
# Found Hot Air
# Found Love, Antosha
# Found Leto
# Found The Tomorrow Man
# Found Asako I & II
# Found The Sun Is Also a Star
# Found Shéhérazade
# Found Long Shot
# Found Clara
# Found Kalank
# Found Rafiki
# Found Diane
# Found Five Feet Apart
# Found Ash Is Purest White
# Found Gloria Bell
# Found Black Mother
# Found The Hole in the Ground
# Found How to Train Your Dragon: The Hidden World
# Found A Tuba to Cuba
# Found Fighting With My Family
# Found Sorry Angel
# Found Berlin, I Love You
# Found Untogether
# Found Cold War
# Found If Beale Street Could Talk
# Found Asher
# Found The Party
# Found The Great Pretender
# Found Sicilian Ghost Story
# Found The New Romantic
# Found Pimp
# Found In a Relationship
# Found They
# Found Burning,
# Found After Everything,
# Found Quincy
# Found Love, Gilda,
# Found Tea With the Dames,
# Found Bel Canto,
# Found The Citizen,
# Found Love, Cecil,
# Found How to Talk to Girls at Parties
# Found Rogers Park,
# Found Love & Bananas,
# Found Godard Mon Amour
# Found Submergence,
# Found Love After Love,
# Found Outside In
# Found Love, Simon,
# Found Keep the Change,
# Found The Party
# Found The Housemaid,
# Found Forever My Girl,
# Found Kangaroo: A Love-Hate Story
# Found Lover for a Day
# Found Youth,
# Found Killing for Love
# Found The Shape of Water
# Found Love Beats Rhymes,
# Found Cuba and the Cameraman
# Found On the Beach at Night Alone
# Found Thelma,
# Found Hello Again,
# Found It Happened in L.A.,
# Found God
# Found The Mountain Between Us
# Found Dina,
# Found In Search of Fellini
# Found Woodpeckers,
# Found I Do ... Until I Don
# Found Tales of an Immoral Couple
# Found After Love
# Found The Last Face
# Found Women Who Kill,
# Found False Confessions,
# Found None
# Found The Big Sick,
# Found Lost in Paris
# Found Vincent N Roxxy,
# Found Everything, Everything
# Found Hounds of Love
# Found Harold and Lillian
# Found The Happiest Day in the Life of Olli Maki,
# Found The Promise
# Found Frantz,
# Found The Other Half
# Found The Ottoman Lieutenant
# Found Love & Taxes
# Found Everybody Loves Somebody,
# Found Kedi,

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Convert each dictionary in the list to a JSON string
tmdb_movies_list_strings = [json.dumps(movie, indent=4) for movie in tmdb_movies_list[:5]]

# Print the results to see the JSON strings
for movie_str in tmdb_movies_list_strings:
    print(movie_str)
# Out:
# {
#     "title": "The Attachment Diaries",
#     "original_title": "El apego",
#     "budget": 0,
#     "original_language": "es",
#     "homepage": "",
#     "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#     "popularity": 6.367,
#     "runtime": 102,
#     "revenue": 0,
#     "release_date": "2021-10-07",
#     "vote_average": 3.0,
#     "vote_count": 4,
#     "genres": [
#         "Drama",
#         "Mystery",
#         "Thriller",
#         "Horror"
#     ],
#     "spoken_languages": [
#         "Spanish"
#     ],
#     "production_countries": [
#         "Argentina"
#     ]
# }
# {
#     "title": "What...",
#     "original_title": "What...",
#     "budget": 0,
#     "original_language": "en",
#     "homepage": "",
#     "overview": "It's another ordinary day for Ricky, until he meets the one person he never thought he would meet.",
#     "popularity": 2.957,
#     "runtime": 0,
#     "revenue": 0,
#     "release_date": "2024-05-31",
#     "vote_average": 0.0,
#     "vote_count": 0,
#     "genres": [
#         "Comedy",
#         "Drama"
#     ],
#     "spoken_languages": [
#         "English"
#     ],
#     "production_countries": [
#         "Australia"
#     ]
# }
# {
#     "title": "You Can Live Forever",
#     "original_title": "You Can Live Forever",
#     "budget": 0,
#     "original_language": "en",
#     "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#     "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#     "popularity": 39.921,
#     "runtime": 96,
#     "revenue": 15055,
#     "release_date": "2023-03-24",
#     "vote_average": 6.6,
#     "vote_count": 34,
#     "genres": [
#         "Drama",
#         "Romance"
#     ],
#     "spoken_languages": [
#         "English",
#         "French"
#     ],
#     "production_countries": [
#         "Canada",
#         "United States of America"
#     ]
# }
# {
#     "title": "A Tourist's Guide to Love",
#     "original_title": "A Tourist's Guide to Love",
#     "budget": 0,
#     "original_language": "en",
#     "homepage": "https://www.netflix.com/title/81424906",
#     "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#     "popularity": 28.325,
#     "runtime": 96,
#     "revenue": 0,
#     "release_date": "2023-04-21",
#     "vote_average": 6.3,
#     "vote_count": 158,
#     "genres": [
#         "Romance",
#         "Comedy"
#     ],
#     "spoken_languages": [
#         "English",
#         "Vietnamese"
#     ],
#     "production_countries": [
#         "United States of America"
#     ]
# }
# {
#     "title": "Other People",
#     "original_title": "Other People",
#     "budget": 0,
#     "original_language": "en",
#     "homepage": "",
#     "overview": "David, a struggling comedy writer fresh off from breaking up with his boyfriend, moves from New York City to Sacramento to help his sick mother. Living with his conservative father and much-younger sisters for the first time in ten years, he feels like a stranger in his childhood home. As his mother\u2019s health declines, David frantically tries to extract meaning from this horrible experience and convince everyone (including himself) that he's \"doing okay.\u201d",
#     "popularity": 25.082,
#     "runtime": 97,
#     "revenue": 93000,
#     "release_date": "2016-09-09",
#     "vote_average": 6.3,
#     "vote_count": 193,
#     "genres": [
#         "Comedy",
#         "Drama"
#     ],
#     "spoken_languages": [
#         "English"
#     ],
#     "production_countries": [
#         "United States of America"
#     ]
# }

# %%
# Convert the results to a DataFrame
tmdb_search_results_df = pd.json_normalize(tmdb_movies_list)
tmdb_search_results_df
# Out:
#                          title             original_title    budget  \
# 0       The Attachment Diaries                   El apego         0
# 1                      What...                    What...         0
# 2         You Can Live Forever       You Can Live Forever         0
# 3    A Tourist's Guide to Love  A Tourist's Guide to Love         0
# 4                 Other People               Other People         0
# ..                         ...                        ...       ...
# 194             The Other Half             The Other Half         0
# 195     The Ottoman Lieutenant     The Ottoman Lieutenant  40000000
# 196         Love Lies Bleeding         Love Lies Bleeding         0
# 197   Everybody Loves Somebody   Everybody Loves Somebody   2000000
# 198                       Kedi                       கேடி         0
#
#     original_language                                           homepage  \
# 0                  es
# 1                  en
# 2                  en  https://gooddeedentertainment.com/you-can-live...
# 3                  en             https://www.netflix.com/title/81424906
# 4                  en
# ..                ...                                                ...
# 194                en                      http://theotherhalfmovie.com/
# 195                en  https://www.uphe.com/movies/the-ottoman-lieute...
# 196                en             https://tickets.loveliesbleeding.movie
# 197                en
# 198                ta
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       6.367      102
# 1    It's another ordinary day for Ricky, until he ...       2.957        0
# 2    When Jaime, a gay teenager, is sent to live in...      39.921       96
# 3    After an unexpected break up, a travel executi...      28.325       96
# 4    David, a struggling comedy writer fresh off fr...      25.082       97
# ..                                                 ...         ...      ...
# 194  A grief-stricken man and a bipolar woman fall ...       9.299      103
# 195  Lillie, a determined American woman, ventures ...      21.589      111
# 196  Reclusive gym manager Lou falls hard for Jacki...     477.088      104
# 197  On the surface, Clara Barron seems to have it ...      12.904      102
# 198  A happy-go-lucky student at a university gets ...       2.783      189
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         3.000           4
# 1          0   2024-05-31         0.000           0
# 2      15055   2023-03-24         6.600          34
# 3          0   2023-04-21         6.300         158
# 4      93000   2016-09-09         6.300         193
# ..       ...          ...           ...         ...
# 194        0   2016-12-02         6.300          24
# 195   413844   2017-03-10         6.173         246
# 196  8770948   2024-03-08         7.044         103
# 197        0   2017-02-10         6.600         158
# 198        0   2006-09-24         4.000           2
#
#                                  genres       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]              [Spanish]
# 1                       [Comedy, Drama]              [English]
# 2                      [Drama, Romance]      [English, French]
# 3                     [Romance, Comedy]  [English, Vietnamese]
# 4                       [Comedy, Drama]              [English]
# ..                                  ...                    ...
# 194                    [Drama, Romance]              [English]
# 195               [Romance, Drama, War]     [Turkish, English]
# 196          [Crime, Romance, Thriller]              [English]
# 197                   [Romance, Comedy]     [English, Spanish]
# 198                           [Romance]                [Tamil]
#
#                            production_countries
# 0                                   [Argentina]
# 1                                   [Australia]
# 2            [Canada, United States of America]
# 3                    [United States of America]
# 4                    [United States of America]
# ..                                          ...
# 194                                    [Canada]
# 195          [Turkey, United States of America]
# 196  [United Kingdom, United States of America]
# 197                                    [Mexico]
# 198                                     [India]
#
# [199 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df, tmdb_search_results_df, on="title", how="inner")
merged_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/20/movies/othe...
# 3    https://www.nytimes.com/2023/04/13/movies/one-...
# 4    https://www.nytimes.com/2023/04/13/movies/the-...
# ..                                                 ...
# 141  https://www.nytimes.com/2017/05/18/movies/ever...
# 142  https://www.nytimes.com/2017/05/11/movies/houn...
# 143  https://www.nytimes.com/2017/04/20/movies/the-...
# 144  https://www.nytimes.com/2017/03/09/movies/the-...
# 145  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 3    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 4    There’s not much Lennon music heard in this do...  The New York Times
# ..                                                 ...                 ...
# 141  Amandla Stenberg plays a teenager with an immu...  The New York Times
# 142  This feature debut of the Australian filmmaker...  The New York Times
# 143  Oscar Isaac, Christian Bale and Charlotte Le B...  The New York Times
# 144  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 145  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Zlotowski, Rebecca;cr...
# 3    subject: Movies;persons: Bracey, Luke (1989- )...
# 4    subject: Documentary Films and Programs;creati...
# ..                                                 ...
# 141  subject: Movies;creative_works: Everything, Ev...
# 142  subject: Movies;creative_works: Hounds of Love...
# 143  subject: Movies;creative_works: The Promise (M...
# 144  subject: Movies;creative_works: The Other Half...
# 145  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-20T15:35:13+0000         801
# 3    2023-04-13T11:00:06+0000         320
# 4    2023-04-13T11:00:03+0000         327
# ..                        ...         ...
# 141  2017-05-18T21:02:53+0000         270
# 142  2017-05-11T20:16:51+0000         280
# 143  2017-04-20T16:49:46+0000         455
# 144  2017-03-09T21:54:58+0000         251
# 145  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 3       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 4    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# ..                                                 ...             ...
# 141  Review: ‘Everything, Everything’ Pits Love Aga...            None
# 142  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
# 143  Review: ‘The Promise’ Finds a Love Triangle in...            None
# 144  Review: A Combustible Pair Find Love in ‘The O...            None
# 145  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 141                    None
# 142                    None
# 143                    None
# 144                    None
# 145                    None
#
#                                headline.print_headline  ...  \
# 0                               The Attachment Diaries  ...
# 1                                 You Can Live Forever  ...
# 2               Intoxicating Love With a Sobering Turn  ...
# 3                                       One True Loves  ...
# 4                      The Lost Weekend:  A Love Story  ...
# ..                                                 ...  ...
# 141                             Everything, Everything  ...
# 142                                     Hounds of Love  ...
# 143              A Love Triangle, Near the Front Lines  ...
# 144  Review: A Combustible Pair Find Love in ‘The O...  ...
# 145  Review: Love as the World Wars, in ‘The Ottoma...  ...
#
#                                               overview popularity runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...      6.367     102
# 1    When Jaime, a gay teenager, is sent to live in...     39.921      96
# 2    David, a struggling comedy writer fresh off fr...     25.082      97
# 3    Emma and Jesse are living the perfect life tog...     18.075     100
# 4    May Pang lovingly recounts her life in rock & ...     11.276      95
# ..                                                 ...        ...     ...
# 141  A teenager who's lived a sheltered life becaus...     42.659      96
# 142  When Vicki Maloney is randomly abducted from a...     26.320     108
# 143  Set during the last days of the Ottoman Empire...     17.598     133
# 144  A grief-stricken man and a bipolar woman fall ...      9.299     103
# 145  Lillie, a determined American woman, ventures ...     21.589     111
#
#       revenue release_date vote_average vote_count  \
# 0           0   2021-10-07        3.000          4
# 1       15055   2023-03-24        6.600         34
# 2       93000   2016-09-09        6.300        193
# 3       37820   2023-04-07        6.406         69
# 4       77145   2023-04-13        6.000          2
# ..        ...          ...          ...        ...
# 141  61621140   2017-05-18        7.246       3635
# 142         0   2016-10-07        6.100        326
# 143  12448676   2016-12-02        6.914        451
# 144         0   2016-12-02        6.300         24
# 145    413844   2017-03-10        6.173        246
#
#                                  genres                     spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]                            [Spanish]
# 1                      [Drama, Romance]                    [English, French]
# 2                       [Comedy, Drama]                            [English]
# 3              [Romance, Drama, Comedy]                   [English, Spanish]
# 4                         [Documentary]                            [English]
# ..                                  ...                                  ...
# 141                    [Drama, Romance]                            [English]
# 142              [Crime, Drama, Horror]                            [English]
# 143           [History, Romance, Drama]  [Armenian, German, English, French]
# 144                    [Drama, Romance]                            [English]
# 145               [Romance, Drama, War]                   [Turkish, English]
#
#                            production_countries
# 0                                   [Argentina]
# 1            [Canada, United States of America]
# 2                    [United States of America]
# 3    [Czech Republic, United States of America]
# 4                    [United States of America]
# ..                                          ...
# 141                  [United States of America]
# 142                                 [Australia]
# 143           [Spain, United States of America]
# 144                                    [Canada]
# 145          [Turkey, United States of America]
#
# [146 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["spoken_languages", "genres", "production_countries"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str).replace(r"[\[\]'']", "", regex=True)


# Display the fixed DataFrame
merged_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/20/movies/othe...
# 3    https://www.nytimes.com/2023/04/13/movies/one-...
# 4    https://www.nytimes.com/2023/04/13/movies/the-...
# ..                                                 ...
# 141  https://www.nytimes.com/2017/05/18/movies/ever...
# 142  https://www.nytimes.com/2017/05/11/movies/houn...
# 143  https://www.nytimes.com/2017/04/20/movies/the-...
# 144  https://www.nytimes.com/2017/03/09/movies/the-...
# 145  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 3    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 4    There’s not much Lennon music heard in this do...  The New York Times
# ..                                                 ...                 ...
# 141  Amandla Stenberg plays a teenager with an immu...  The New York Times
# 142  This feature debut of the Australian filmmaker...  The New York Times
# 143  Oscar Isaac, Christian Bale and Charlotte Le B...  The New York Times
# 144  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 145  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Zlotowski, Rebecca;cr...
# 3    subject: Movies;persons: Bracey, Luke (1989- )...
# 4    subject: Documentary Films and Programs;creati...
# ..                                                 ...
# 141  subject: Movies;creative_works: Everything, Ev...
# 142  subject: Movies;creative_works: Hounds of Love...
# 143  subject: Movies;creative_works: The Promise (M...
# 144  subject: Movies;creative_works: The Other Half...
# 145  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-20T15:35:13+0000         801
# 3    2023-04-13T11:00:06+0000         320
# 4    2023-04-13T11:00:03+0000         327
# ..                        ...         ...
# 141  2017-05-18T21:02:53+0000         270
# 142  2017-05-11T20:16:51+0000         280
# 143  2017-04-20T16:49:46+0000         455
# 144  2017-03-09T21:54:58+0000         251
# 145  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 3       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 4    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# ..                                                 ...             ...
# 141  Review: ‘Everything, Everything’ Pits Love Aga...            None
# 142  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
# 143  Review: ‘The Promise’ Finds a Love Triangle in...            None
# 144  Review: A Combustible Pair Find Love in ‘The O...            None
# 145  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 141                    None
# 142                    None
# 143                    None
# 144                    None
# 145                    None
#
#                                headline.print_headline  ...  \
# 0                               The Attachment Diaries  ...
# 1                                 You Can Live Forever  ...
# 2               Intoxicating Love With a Sobering Turn  ...
# 3                                       One True Loves  ...
# 4                      The Lost Weekend:  A Love Story  ...
# ..                                                 ...  ...
# 141                             Everything, Everything  ...
# 142                                     Hounds of Love  ...
# 143              A Love Triangle, Near the Front Lines  ...
# 144  Review: A Combustible Pair Find Love in ‘The O...  ...
# 145  Review: Love as the World Wars, in ‘The Ottoma...  ...
#
#                                               overview popularity runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...      6.367     102
# 1    When Jaime, a gay teenager, is sent to live in...     39.921      96
# 2    David, a struggling comedy writer fresh off fr...     25.082      97
# 3    Emma and Jesse are living the perfect life tog...     18.075     100
# 4    May Pang lovingly recounts her life in rock & ...     11.276      95
# ..                                                 ...        ...     ...
# 141  A teenager who's lived a sheltered life becaus...     42.659      96
# 142  When Vicki Maloney is randomly abducted from a...     26.320     108
# 143  Set during the last days of the Ottoman Empire...     17.598     133
# 144  A grief-stricken man and a bipolar woman fall ...      9.299     103
# 145  Lillie, a determined American woman, ventures ...     21.589     111
#
#       revenue release_date vote_average vote_count  \
# 0           0   2021-10-07        3.000          4
# 1       15055   2023-03-24        6.600         34
# 2       93000   2016-09-09        6.300        193
# 3       37820   2023-04-07        6.406         69
# 4       77145   2023-04-13        6.000          2
# ..        ...          ...          ...        ...
# 141  61621140   2017-05-18        7.246       3635
# 142         0   2016-10-07        6.100        326
# 143  12448676   2016-12-02        6.914        451
# 144         0   2016-12-02        6.300         24
# 145    413844   2017-03-10        6.173        246
#
#                                genres                   spoken_languages  \
# 0    Drama, Mystery, Thriller, Horror                            Spanish
# 1                      Drama, Romance                    English, French
# 2                       Comedy, Drama                            English
# 3              Romance, Drama, Comedy                   English, Spanish
# 4                         Documentary                            English
# ..                                ...                                ...
# 141                    Drama, Romance                            English
# 142              Crime, Drama, Horror                            English
# 143           History, Romance, Drama  Armenian, German, English, French
# 144                    Drama, Romance                            English
# 145               Romance, Drama, War                   Turkish, English
#
#                          production_countries
# 0                                   Argentina
# 1            Canada, United States of America
# 2                    United States of America
# 3    Czech Republic, United States of America
# 4                    United States of America
# ..                                        ...
# 141                  United States of America
# 142                                 Australia
# 143           Spain, United States of America
# 144                                    Canada
# 145          Turkey, United States of America
#
# [146 rows x 31 columns]

# %%
# Drop "byline.person" column
merged_df.drop('byline.person', axis=1, inplace=True)
merged_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/20/movies/othe...
# 3    https://www.nytimes.com/2023/04/13/movies/one-...
# 4    https://www.nytimes.com/2023/04/13/movies/the-...
# ..                                                 ...
# 141  https://www.nytimes.com/2017/05/18/movies/ever...
# 142  https://www.nytimes.com/2017/05/11/movies/houn...
# 143  https://www.nytimes.com/2017/04/20/movies/the-...
# 144  https://www.nytimes.com/2017/03/09/movies/the-...
# 145  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 3    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 4    There’s not much Lennon music heard in this do...  The New York Times
# ..                                                 ...                 ...
# 141  Amandla Stenberg plays a teenager with an immu...  The New York Times
# 142  This feature debut of the Australian filmmaker...  The New York Times
# 143  Oscar Isaac, Christian Bale and Charlotte Le B...  The New York Times
# 144  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 145  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Zlotowski, Rebecca;cr...
# 3    subject: Movies;persons: Bracey, Luke (1989- )...
# 4    subject: Documentary Films and Programs;creati...
# ..                                                 ...
# 141  subject: Movies;creative_works: Everything, Ev...
# 142  subject: Movies;creative_works: Hounds of Love...
# 143  subject: Movies;creative_works: The Promise (M...
# 144  subject: Movies;creative_works: The Other Half...
# 145  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-20T15:35:13+0000         801
# 3    2023-04-13T11:00:06+0000         320
# 4    2023-04-13T11:00:03+0000         327
# ..                        ...         ...
# 141  2017-05-18T21:02:53+0000         270
# 142  2017-05-11T20:16:51+0000         280
# 143  2017-04-20T16:49:46+0000         455
# 144  2017-03-09T21:54:58+0000         251
# 145  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 3       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 4    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# ..                                                 ...             ...
# 141  Review: ‘Everything, Everything’ Pits Love Aga...            None
# 142  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
# 143  Review: ‘The Promise’ Finds a Love Triangle in...            None
# 144  Review: A Combustible Pair Find Love in ‘The O...            None
# 145  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 141                    None
# 142                    None
# 143                    None
# 144                    None
# 145                    None
#
#                                headline.print_headline  ...  \
# 0                               The Attachment Diaries  ...
# 1                                 You Can Live Forever  ...
# 2               Intoxicating Love With a Sobering Turn  ...
# 3                                       One True Loves  ...
# 4                      The Lost Weekend:  A Love Story  ...
# ..                                                 ...  ...
# 141                             Everything, Everything  ...
# 142                                     Hounds of Love  ...
# 143              A Love Triangle, Near the Front Lines  ...
# 144  Review: A Combustible Pair Find Love in ‘The O...  ...
# 145  Review: Love as the World Wars, in ‘The Ottoma...  ...
#
#                                               overview popularity runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...      6.367     102
# 1    When Jaime, a gay teenager, is sent to live in...     39.921      96
# 2    David, a struggling comedy writer fresh off fr...     25.082      97
# 3    Emma and Jesse are living the perfect life tog...     18.075     100
# 4    May Pang lovingly recounts her life in rock & ...     11.276      95
# ..                                                 ...        ...     ...
# 141  A teenager who's lived a sheltered life becaus...     42.659      96
# 142  When Vicki Maloney is randomly abducted from a...     26.320     108
# 143  Set during the last days of the Ottoman Empire...     17.598     133
# 144  A grief-stricken man and a bipolar woman fall ...      9.299     103
# 145  Lillie, a determined American woman, ventures ...     21.589     111
#
#       revenue release_date vote_average vote_count  \
# 0           0   2021-10-07        3.000          4
# 1       15055   2023-03-24        6.600         34
# 2       93000   2016-09-09        6.300        193
# 3       37820   2023-04-07        6.406         69
# 4       77145   2023-04-13        6.000          2
# ..        ...          ...          ...        ...
# 141  61621140   2017-05-18        7.246       3635
# 142         0   2016-10-07        6.100        326
# 143  12448676   2016-12-02        6.914        451
# 144         0   2016-12-02        6.300         24
# 145    413844   2017-03-10        6.173        246
#
#                                genres                   spoken_languages  \
# 0    Drama, Mystery, Thriller, Horror                            Spanish
# 1                      Drama, Romance                    English, French
# 2                       Comedy, Drama                            English
# 3              Romance, Drama, Comedy                   English, Spanish
# 4                         Documentary                            English
# ..                                ...                                ...
# 141                    Drama, Romance                            English
# 142              Crime, Drama, Horror                            English
# 143           History, Romance, Drama  Armenian, German, English, French
# 144                    Drama, Romance                            English
# 145               Romance, Drama, War                   Turkish, English
#
#                          production_countries
# 0                                   Argentina
# 1            Canada, United States of America
# 2                    United States of America
# 3    Czech Republic, United States of America
# 4                    United States of America
# ..                                        ...
# 141                  United States of America
# 142                                 Australia
# 143           Spain, United States of America
# 144                                    Canada
# 145          Turkey, United States of America
#
# [146 rows x 30 columns]

# %%
# Delete duplicate rows and reset index

# Convert the 'web_url' column to a hashable type, such as string
print(type(merged_df['web_url']))
merged_df['web_url'] = merged_df['web_url'].astype(str)

# Delete duplicate rows and reset index
merged_df = merged_df.drop_duplicates(subset='web_url', keep='first').reset_index(drop=True)
merged_df
# Out:
# <class 'pandas.core.series.Series'>
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/20/movies/othe...
# 3    https://www.nytimes.com/2023/04/13/movies/one-...
# 4    https://www.nytimes.com/2023/04/13/movies/the-...
# ..                                                 ...
# 136  https://www.nytimes.com/2017/05/18/movies/ever...
# 137  https://www.nytimes.com/2017/05/11/movies/houn...
# 138  https://www.nytimes.com/2017/04/20/movies/the-...
# 139  https://www.nytimes.com/2017/03/09/movies/the-...
# 140  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 3    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 4    There’s not much Lennon music heard in this do...  The New York Times
# ..                                                 ...                 ...
# 136  Amandla Stenberg plays a teenager with an immu...  The New York Times
# 137  This feature debut of the Australian filmmaker...  The New York Times
# 138  Oscar Isaac, Christian Bale and Charlotte Le B...  The New York Times
# 139  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 140  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Zlotowski, Rebecca;cr...
# 3    subject: Movies;persons: Bracey, Luke (1989- )...
# 4    subject: Documentary Films and Programs;creati...
# ..                                                 ...
# 136  subject: Movies;creative_works: Everything, Ev...
# 137  subject: Movies;creative_works: Hounds of Love...
# 138  subject: Movies;creative_works: The Promise (M...
# 139  subject: Movies;creative_works: The Other Half...
# 140  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-20T15:35:13+0000         801
# 3    2023-04-13T11:00:06+0000         320
# 4    2023-04-13T11:00:03+0000         327
# ..                        ...         ...
# 136  2017-05-18T21:02:53+0000         270
# 137  2017-05-11T20:16:51+0000         280
# 138  2017-04-20T16:49:46+0000         455
# 139  2017-03-09T21:54:58+0000         251
# 140  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 3       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 4    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# ..                                                 ...             ...
# 136  Review: ‘Everything, Everything’ Pits Love Aga...            None
# 137  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
# 138  Review: ‘The Promise’ Finds a Love Triangle in...            None
# 139  Review: A Combustible Pair Find Love in ‘The O...            None
# 140  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 136                    None
# 137                    None
# 138                    None
# 139                    None
# 140                    None
#
#                                headline.print_headline  ...  \
# 0                               The Attachment Diaries  ...
# 1                                 You Can Live Forever  ...
# 2               Intoxicating Love With a Sobering Turn  ...
# 3                                       One True Loves  ...
# 4                      The Lost Weekend:  A Love Story  ...
# ..                                                 ...  ...
# 136                             Everything, Everything  ...
# 137                                     Hounds of Love  ...
# 138              A Love Triangle, Near the Front Lines  ...
# 139  Review: A Combustible Pair Find Love in ‘The O...  ...
# 140  Review: Love as the World Wars, in ‘The Ottoma...  ...
#
#                                               overview popularity runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...      6.367     102
# 1    When Jaime, a gay teenager, is sent to live in...     39.921      96
# 2    David, a struggling comedy writer fresh off fr...     25.082      97
# 3    Emma and Jesse are living the perfect life tog...     18.075     100
# 4    May Pang lovingly recounts her life in rock & ...     11.276      95
# ..                                                 ...        ...     ...
# 136  A teenager who's lived a sheltered life becaus...     42.659      96
# 137  When Vicki Maloney is randomly abducted from a...     26.320     108
# 138  Set during the last days of the Ottoman Empire...     17.598     133
# 139  A grief-stricken man and a bipolar woman fall ...      9.299     103
# 140  Lillie, a determined American woman, ventures ...     21.589     111
#
#       revenue release_date vote_average vote_count  \
# 0           0   2021-10-07        3.000          4
# 1       15055   2023-03-24        6.600         34
# 2       93000   2016-09-09        6.300        193
# 3       37820   2023-04-07        6.406         69
# 4       77145   2023-04-13        6.000          2
# ..        ...          ...          ...        ...
# 136  61621140   2017-05-18        7.246       3635
# 137         0   2016-10-07        6.100        326
# 138  12448676   2016-12-02        6.914        451
# 139         0   2016-12-02        6.300         24
# 140    413844   2017-03-10        6.173        246
#
#                                genres                   spoken_languages  \
# 0    Drama, Mystery, Thriller, Horror                            Spanish
# 1                      Drama, Romance                    English, French
# 2                       Comedy, Drama                            English
# 3              Romance, Drama, Comedy                   English, Spanish
# 4                         Documentary                            English
# ..                                ...                                ...
# 136                    Drama, Romance                            English
# 137              Crime, Drama, Horror                            English
# 138           History, Romance, Drama  Armenian, German, English, French
# 139                    Drama, Romance                            English
# 140               Romance, Drama, War                   Turkish, English
#
#                          production_countries
# 0                                   Argentina
# 1            Canada, United States of America
# 2                    United States of America
# 3    Czech Republic, United States of America
# 4                    United States of America
# ..                                        ...
# 136                  United States of America
# 137                                 Australia
# 138           Spain, United States of America
# 139                                    Canada
# 140          Turkey, United States of America
#
# [141 rows x 30 columns]

# %%
# Export data to CSV without the index
os.makedirs('output')
merged_df.to_csv('output/collected_data.csv', index=False)
